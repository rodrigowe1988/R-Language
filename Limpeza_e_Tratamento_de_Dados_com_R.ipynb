# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigowe1988/R-Language/blob/main/Limpeza_e_Tratamento_de_Dados_com_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar dados, strings vazias com NA, string como fatores
dados = read.csv("Churn.csv", sep=";", na.strings="", stringsAsFactors=T)
head(dados)
summary(dados)
# Out:
#   X0 X1  X2 X3        X4 X4.1 X6       X7 X8 X9 X10      X11
# 1 1  619 RS Feminino  42 2           0 1  1  1  10134888 1
# 2 2  608 SC Feminino  41 1     8380786 1  0  1  11254258 0
# 3 3  502 RS Feminino  42 8     1596608 3  1  0  11393157 1
# 4 4  699 RS Feminino  39 1           0 2  0  0   9382663 0
# 5 5  850 SC Feminino  43 2    12551082 1  1  1    790841 0
# 6 6  645 SC Masculino 44 8    11375578 2  1  0  14975671 1
#        X0               X1         X2              X3            X4
#  Min.   :   1.0   Min.   :376.0   PR:257   F        :  2   Min.   :-20.0
#  1st Qu.: 251.5   1st Qu.:580.0   RP:  1   Fem      :  1   1st Qu.: 32.0
#  Median : 501.0   Median :653.0   RS:478   Feminino :461   Median : 37.0
#  Mean   : 500.9   Mean   :648.6   SC:258   M        :  6   Mean   : 38.9
#  3rd Qu.: 750.5   3rd Qu.:721.0   SP:  4   Masculino:521   3rd Qu.: 44.0
#  Max.   :1000.0   Max.   :850.0   TD:  1   NA's     :  8   Max.   :140.0
#
# ...

# %% [markdown]
# Observação: os fatores, diferentemente das Strings, são dados categorizados, possuem um valor, NÃO sendo somente letras ou palavras.

# %%
#renomeando as colunas
colnames(dados) = c('Id', 'Score', 'Estado', 'Genero', 'Idade', 'Patrimonio', 'Saldo', 'Produtos', 'TemCartaoCredito', 'Ativo', 'Salario', 'Saiu')
head(dados)
# Out:
#   Id Score Estado Genero    Idade Patrimonio Saldo    Produtos TemCartaoCredito
# 1 1  619   RS     Feminino  42    2                 0 1        1
# 2 2  608   SC     Feminino  41    1           8380786 1        0
# 3 3  502   RS     Feminino  42    8           1596608 3        1
# 4 4  699   RS     Feminino  39    1                 0 2        0
# 5 5  850   SC     Feminino  43    2          12551082 1        1
# 6 6  645   SC     Masculino 44    8          11375578 2        1
#   Ativo Salario  Saiu
# 1 1     10134888 1
# 2 1     11254258 0
# 3 0     11393157 1
# 4 0      9382663 0
# 5 1       790841 0
# 6 0     14975671 1

# %%
#Estados
counts = table(dados$Estado)
barplot(counts, main="Estados", xlab = "Estados")
# Out:
# Plot with title “Estados”

# %%
#Gênero 
counts = table(dados$Genero)
barplot(counts, main = "Gêneros", xlab = "Gêneros")
# Out:
# Plot with title “Gêneros”

# %% [markdown]
# ##Explorando dados numéricos

# %% [markdown]
# ###Coluna Score

# %%
summary(dados$Score)
boxplot(dados$Score, main='Boxplot da coluna Score')
hist(dados$Score, main='Histograma da coluna Score', xlab = 'Score')
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   376.0   580.0   653.0   648.6   721.0   850.0
# Plot with title “Boxplot da coluna Score”
# Plot with title “Histograma da coluna Score”

# %% [markdown]
# ###Coluna Idade

# %%
summary(dados$Idade)
boxplot(dados$Idad, main='Boxplot da coluna Idade')
hist(dados$Idade, main='Histograma da coluna Idade', xlab = 'Idade')
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   -20.0    32.0    37.0    38.9    44.0   140.0
# Plot with title “Boxplot da coluna Idade”
# Plot with title “Histograma da coluna Idade”

# %% [markdown]
# ###Coluna Saldo

# %%
summary(dados$Saldo)
boxplot(dados$Saldo, main='Boxplot da coluna Saldo')
hist(dados$Saldo, main='Histograma da coluna Saldo', xlab = 'Saldo')
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#        0        0  8958835  7164928 12586844 21177431
# Plot with title “Boxplot da coluna Saldo”
# Plot with title “Histograma da coluna Saldo”

# %% [markdown]
# ###Coluna Salario

# %%
summary(dados$Salario)
boxplot(dados$Salario, main='Boxplot da coluna Salario')
hist(dados$Salario, main='Histograma da coluna Salario', xlab = 'Salário')
#outline=F para não mostrar os outliers junto
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.      NA's
# 9.677e+03 3.029e+06 8.703e+06 3.529e+07 1.405e+07 1.193e+10         7
# Plot with title “Boxplot da coluna Salario”
# Plot with title “Histograma da coluna Salario”

# %% [markdown]
# ##Valores Faltantes, NA's e outras modificações mais

# %%
dados[!complete.cases(dados$Salario),]
# Out:
#     Id  Score Estado Genero    Idade Patrimonio Saldo    Produtos
# 18   18 549   SC     Feminino  24     9                0 2
# 53   53 788   RS     Feminino  33     5                0 2
# 180 181 754   PR     Feminino  55     3         16160881 1
# 331 332 656   RS     Masculino 50     7                0 2
# 427 428 492   PR     Masculino 39    10         12457665 2
# 551 552 721   PR     Feminino  36     3          6525307 2
# 984 985 614   PR     Feminino  35     6         12810028 1
#     TemCartaoCredito Ativo Salario Saiu
# 18  1                1     NA      0
# 53  0                0     NA      0
# 180 1                0     NA      1
# 331 0                1     NA      0
# 427 1                0     NA      0
# 551 1                0     NA      0
# 984 0                0     NA      1

# %% [markdown]
# Note que temos 7 linhas com valores NA na coluna Salario.

# %%
summary(dados$Salario)
mediana_salario = median(dados$Salario, na.rm=T)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.      NA's
# 9.677e+03 3.029e+06 8.703e+06 3.529e+07 1.405e+07 1.193e+10         7

# %%
#atribuindo a mediana aos valores NA's
dados[is.na(dados$Salario), ]$Salario = mediana_salario

# %%
#verificar se os dados NA's foram substituidos
dados[!complete.cases(dados$Salario),]
# Out:
#      Id Score Estado Genero Idade Patrimonio Saldo Produtos TemCartaoCredito
#      Ativo Salario Saiu
